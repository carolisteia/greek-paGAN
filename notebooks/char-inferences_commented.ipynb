# %%
# Import necessary libraries and modules
# Importing Path for file path handling across different operating systems.
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# Set up directory paths for input and output data storage
input_folder= Path('/kaggle/input/')
output_folder=Path('/kaggle/working/')

# %%
# Install required Python packages not included in the standard library
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.0/793.0 kB 21.4 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries and modules
# Import YOLO and SETTINGS from the ultralytics library for object detection tasks.
from ultralytics import YOLO, SETTINGS

# %%
# Disable Weights & Biases logging for this session.
SETTINGS['wandb'] = False

# %%
# Train machine learning models
# Load a YOLO model for object detection, using a pre-trained model specification.
model = YOLO('yolov8n-cls')
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [00:00<00:00, 104MB/s]

# %%
# Train machine learning models
# Define paths for input and output data directories.
greek=YOLO(input_folder/'char-class/runs/classify/train/weights/best.pt')

# %%
# !ls /kaggle/input/char-class/yolo_data/test/186_Δ/186_7252_5830.png
# Out:
# 186_10018_15314.png  186_3148_46121.png  186_4960_42874.png  186_7252_5830.png
# 186_10018_15374.png  186_3172_46169.png  186_4960_43154.png  186_7252_6098.png
# 186_10196_16032.png  186_3273_47258.png  186_4961_43724.png  186_7258_10961.png
# 186_10336_16498.png  186_3286_47384.png  186_4962_43759.png  186_7258_11084.png
# 186_10363_17107.png  186_3311_47752.png  186_4964_44372.png  186_7258_11250.png
# 186_10363_17328.png  186_3311_47939.png  186_4965_44518.png  186_7258_11678.png
# 186_10425_17858.png  186_3468_49349.png  186_4965_44550.png  186_7259_12461.png
# 186_10425_17902.png  186_3468_49443.png  186_4981_58122.png  186_7259_13022.png
# 186_10425_17958.png  186_3736_52452.png  186_5004_58429.png  186_7259_13031.png
# 186_10713_19194.png  186_3741_53358.png  186_5071_59274.png  186_7259_13079.png
# 186_10817_20157.png  186_3744_54072.png  186_5671_61573.png  186_7260_6567.png
# 186_10817_20320.png  186_4060_55170.png  186_5_49836.png     186_7260_6714.png
# ...

# %%
# Make predictions with the trained models
# Define paths for input and output data directories.
result = greek.predict(input_folder/'char-class/yolo_data/test/186_Δ/186_7252_5830.png')
# Out:
# image 1/1 /kaggle/input/char-class/yolo_data/test/186_Δ/186_7252_5830.png: 64x64 186_Δ 1.00, 59_Μ 0.00, 17_Ξ 0.00, 120_Λ 0.00, 45_Ω 0.00, 30.8ms
# Speed: 48.6ms preprocess, 30.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
# Make predictions with the trained models
# Processing or analysis step (specific details depend on the line of code).
def get_class_name(path):
    result = greek.predict(path)
    return result[0].names[result[0].probs.top1].split('_')[1]

# %%
# Make predictions with the trained models
# Processing or analysis step (specific details depend on the line of code).
def get_probas(path):
    result = greek.predict(path)
    print( result[0].probs.top5)
    return [result[0].names[class_num].split('_')[1] for class_num in result[0].probs.top5]

# %%
# Define paths for input and output data directories.
get_class_name(input_folder/'char-class/yolo_data/test/186_Δ/186_7252_5830.png')
# Out:
# image 1/1 /kaggle/input/char-class/yolo_data/test/186_Δ/186_7252_5830.png: 64x64 186_Δ 1.00, 59_Μ 0.00, 17_Ξ 0.00, 120_Λ 0.00, 45_Ω 0.00, 6.7ms
# Speed: 2.3ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# 'Δ'

# %%
# Define paths for input and output data directories.
get_probas(input_folder/'char-class/yolo_data/test/186_Δ/186_7252_5830.png')
# Out:
# image 1/1 /kaggle/input/char-class/yolo_data/test/186_Δ/186_7252_5830.png: 64x64 186_Δ 1.00, 59_Μ 0.00, 17_Ξ 0.00, 120_Λ 0.00, 45_Ω 0.00, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# [12, 19, 11, 4, 18]
# ['Δ', 'Μ', 'Ξ', 'Λ', 'Ω']

# %%
# Make predictions with the trained models
# Define paths for input and output data directories.
greek.predict(input_folder/'char-class/yolo_data/test/186_Δ/186_7252_5830.png')[0].probs.top5
# Out:
# image 1/1 /kaggle/input/char-class/yolo_data/test/186_Δ/186_7252_5830.png: 64x64 186_Δ 1.00, 59_Μ 0.00, 17_Ξ 0.00, 120_Λ 0.00, 45_Ω 0.00, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# [12, 19, 11, 4, 18]

# %%
# Make predictions with the trained models
# Define paths for input and output data directories.
greek.predict(input_folder/'char-class/yolo_data/test/186_Δ/186_7252_5830.png')[0].names
# Out:
# image 1/1 /kaggle/input/char-class/yolo_data/test/186_Δ/186_7252_5830.png: 64x64 186_Δ 1.00, 59_Μ 0.00, 17_Ξ 0.00, 120_Λ 0.00, 45_Ω 0.00, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# {0: '100_Ρ',
#  1: '107_Π',
#  2: '111_Γ',
#  3: '119_Ν',
#  4: '120_Λ',
#  5: '144_Ζ',
#  6: '14_Τ',
#  7: '150_Η',
#  8: '161_Υ',
#  9: '169_Ψ',
#  10: '177_Χ',
#  11: '17_Ξ',
#  12: '186_Δ',
#  13: '201_Ο',
#  14: '212_Ι',
#  15: '225_Ϲ',
#  16: '23_Ε',
#  17: '33_Κ',
#  18: '45_Ω',
#  19: '59_Μ',
#  20: '77_Φ',
#  21: '7_Θ',
#  22: '8_Α',
#  23: '9_Β'}

# %%
result[0].names[result[0].probs.top1]
# Out:
# '186_Δ'

# %%
result[0].names
# Out:
# {0: '100_Ρ',
#  1: '107_Π',
#  2: '111_Γ',
#  3: '119_Ν',
#  4: '120_Λ',
#  5: '144_Ζ',
#  6: '14_Τ',
#  7: '150_Η',
#  8: '161_Υ',
#  9: '169_Ψ',
#  10: '177_Χ',
#  11: '17_Ξ',
#  12: '186_Δ',
#  13: '201_Ο',
#  14: '212_Ι',
#  15: '225_Ϲ',
#  16: '23_Ε',
#  17: '33_Κ',
#  18: '45_Ω',
#  19: '59_Μ',
#  20: '77_Φ',
#  21: '7_Θ',
#  22: '8_Α',
#  23: '9_Β'}

# %%
# Resize test images
def resize_images(folder, output, size):
    # Traverse all subdirectories and files in the main directory
    for subdir, _, files in os.walk(folder):
        for file in files:
            file_path = os.path.join(subdir, file)
            # Read the image
            img = cv2.imread(file_path)
            # Resize the image
            img_resized = cv2.resize(img, size, interpolation=cv2.INTER_AREA)

            # Build the output path
            relative_path = os.path.relpath(subdir, folder) # copy the directory structure
            output_subdir = os.path.join(output, relative_path)
            os.makedirs(output_subdir, exist_ok=True)
            output_path = os.path.join(output_subdir, file)
            cv2.imwrite(output_path, img_resized)

# %%
# Define paths for input and output data directories.
data = input_folder/'char-class/yolo_data/test/' 
output = output_folder/'map_red' 
resize_images(data,output,size=(40, 40))
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: profile 'ICC Profile': 'desc': ICC profile tag start not a multiple of 4
# libpng warning: iCCP: profile 'ICC Profile': 'rXYZ': ICC profile tag start not a multiple of 4
# libpng warning: iCCP: profile 'ICC Profile': 'gXYZ': ICC profile tag start not a multiple of 4
# libpng warning: iCCP: profile 'ICC Profile': 'bXYZ': ICC profile tag start not a multiple of 4
# libpng warning: iCCP: profile 'ICC Profile': 'wtpt': ICC profile tag start not a multiple of 4
# libpng warning: iCCP: profile 'ICC Profile': 'bkpt': ICC profile tag start not a multiple of 4
# libpng warning: iCCP: profile 'ICC Profile': 'rTRC': ICC profile tag start not a multiple of 4
# libpng warning: iCCP: profile 'ICC Profile': 'gTRC': ICC profile tag start not a multiple of 4
# libpng warning: iCCP: profile 'ICC Profile': 'bTRC': ICC profile tag start not a multiple of 4
# ...

# %%
186_Δ/186_7252_5830.png

# %%
# Mapping of subfolder names to their indices, which represents the class number of the letters obtained from:

class_alphabet = {'Α': 0, 'Ε': 1, 'I': 2, 'N': 3, 'O': 4, 'Β': 5, 'Γ': 6, 'Δ': 7, 'Ζ': 8, 'Η': 9,
                     'Θ': 10, 'Κ': 11, 'Λ': 12, 'Μ': 13, 'Ξ': 14, 'Π': 15, 'Ρ': 16, 'Τ': 17, 'Υ': 18,
                     'Φ': 19, 'Χ': 20, 'Ψ': 21, 'Ω': 22, 'Ϲ': 23}

# %%
# Load a YOLO model for object detection, using a pre-trained model specification.
def generate_occlusion(image, model, class_id, occlusion_size, step_size):
    image_height, image_width, _ = image.shape
    heatmap = np.zeros((image_height, image_width))

    # Initialize and predict with YOLO model
    predict_model = YOLO(model)
    results = predict_model.predict(image)

    # Check if class_id is in the top5 predicted classes and get initial confidence
    if class_id in results[0].probs.top5:
        rank = results[0].probs.top5.index(class_id)
        initial_confidence = results[0].probs.top5conf[rank]
    else:
        initial_confidence = 0

    # Iterate over each pixel block in the image with given step size
    for y in range(0, image_width - occlusion_size[1] + 1, step_size):
        for x in range(0, image_height - occlusion_size[0] + 1, step_size):

            # Create an occluded version of the image by setting a block to zero
            occluded_image = image.copy()
            occluded_image[x:x + occlusion_size[0], y:y + occlusion_size[1]] = 0

            # Predict with the occluded image
            results = predict_model.predict(occluded_image)

            # Check for class confidence in occluded image and calculate difference
            if class_id in results[0].probs.top5:
                rank = results[0].probs.top5.index(class_id)
                class_confidence = results[0].probs.top5conf[rank]
            else:
                class_confidence = 0

            # Update the heatmap with the reduced confidence due to occlusion
            heatmap[x:x + occlusion_size[0], y:y + occlusion_size[1]] = initial_confidence - class_confidence

    # Normalize the heatmap
    heatmap = (heatmap - np.min(heatmap)) / (np.max(heatmap) - np.min(heatmap))

    return heatmap

# %%
def generate_heatmaps(folder_path, model_path, class_alphabet, occlusion_size, step_size):
    heatmaps = []
    # Traverse all subfolders in the main folder
    for subfolder_name in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder_name)

        # Traverse all files in the subfolder
        for filename in os.listdir(subfolder_path):
            # Full path of the image
            image_path = os.path.join(subfolder_path, filename)

            # Read the image
            image = cv2.imread(image_path, cv2.IMREAD_COLOR)

            # Retrieve the index of the subfolder from the mapping
            class_id = class_alphabet.get(subfolder_name)

            # Generate the heatmap
            heatmap = generate_occlusion(image, model_path, class_id, occlusion_size, step_size)
            heatmaps.append(heatmap)

    return heatmaps

# %%
# Define paths for input and output data directories.
folder_path = output
model_path = input_folder/'char_class/runs/classify/train/weights/best.pt'
occlusion_size = (5,5) 
step_size = 5 
heatmaps = generate_heatmaps(folder_path, model_path, class_alphabet, occlusion_size, step_size)

# %%
def is_valid_heatmap(heatmap):
    if not np.all(np.isfinite(heatmap)):
        return False
    if heatmap.shape != (64, 64):
        return False
    return True

# %%
def overlay(heatmaps):
    # Filter out invalid heatmaps
    valid_heatmaps = [heatmap for heatmap in heatmaps if is_valid_heatmap(heatmap)]

    # Initialize an empty heatmap for summing
    combined_heatmap = np.zeros_like(valid_heatmaps[0], dtype=float)

    # Normalize and add each valid heatmap to the sum
    for heatmap in valid_heatmaps:
        normalized_heatmap = (heatmap - np.min(heatmap)) / (np.max(heatmap) - np.min(heatmap))
        combined_heatmap += normalized_heatmap

    # Calculate the average
    combined_heatmap /= len(valid_heatmaps)

    return combined_heatmap

# %%
# The heatmaps are loaded in grayscale
superposer_heatmap = overlay(heatmaps)

# %%
plt.imshow(superposer_heatmap, cmap='YlGn')
plt.colorbar()
plt.show()
plt.savefig(input_folder/'char_class/map_combined')

# %%
# Overlay the map on an image
def overlay_heatmap(image, heatmap, alpha=0.6):
    heatmap_normalized = (heatmap - np.min(heatmap) / np.max(heatmap) - np.min(heatmap))
    heatmap_colored = cv2.applyColorMap(np.uint8(255 * heatmap_normalized), cv2.COLORMAP_JET)

    overlay = cv2.addWeighted(image, alpha, heatmap_colored, 1 - alpha, 0)
    return overlay

# %%
overlay_image = overlay_heatmap(image, superposer_heatmap)
plt.imshow(cv2.cvtColor(overlay_image, cv2.COLOR_BGR2RGB))
plt.show()
